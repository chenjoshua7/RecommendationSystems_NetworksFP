# %%
import pandas as pd
import numpy as np
import networkx as nx

from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

import matplotlib.pyplot as plt

from tqdm import tqdm # progress bar

# %%
movies = pd.read_csv("../data/movies.csv")
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
ratings = pd.read_csv("../data/ratings.csv")
ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
# Demean ratings
ratings['rating'] = ratings['rating'] - 2.5

# %% [markdown]
# ## Dealing with Duplicate Data

# %%
duplicates = movies[movies.duplicated(subset=['title'], keep=False)]
sorted_duplicates = pd.DataFrame(duplicates.sort_values("title"))

sorted_duplicates
# Out:
#       movieId                                   title  \
# 4169     6003  Confessions of a Dangerous Mind (2002)
# 9106   144606  Confessions of a Dangerous Mind (2002)
# 650       838                             Emma (1996)
# 5601    26958                             Emma (1996)
# 5854    32600                             Eros (2004)
# 9135   147002                             Eros (2004)
# 2141     2851                         Saturn 3 (1980)
# 9468   168358                         Saturn 3 (1980)
# 5931    34048                War of the Worlds (2005)
# 6932    64997                War of the Worlds (2005)
#
#                                    genres
# 4169          Comedy|Crime|Drama|Thriller
# 9106  Comedy|Crime|Drama|Romance|Thriller
# 650                  Comedy|Drama|Romance
# 5601                              Romance
# 5854                                Drama
# 9135                        Drama|Romance
# 2141            Adventure|Sci-Fi|Thriller
# 9468                      Sci-Fi|Thriller
# 5931     Action|Adventure|Sci-Fi|Thriller
# 6932                        Action|Sci-Fi

# %%
duplicateIds = [6003, 26958, 32600, 168358, 64997]
movies = movies[~movies["movieId"].isin(duplicateIds)]

# %% [markdown]
# ## Graphing a Random Sample Network:

# %%
merged_ratings = pd.merge(ratings, movies, on='movieId', how='inner')

# %%
movies_count = merged_ratings.groupby('movieId')['userId'].agg(['count', 'nunique'])
print('Number of movies:', movies_count.shape)
# Filter on movies that have more than 5 ratings
movies_count = movies_count.query('count > 5')
print('Number of movies:', movies_count.shape)

display(movies_count.head(10))

merged_ratings =  merged_ratings[merged_ratings['movieId'].isin(movies_count.index)]
# Out:
# Number of movies: (9719, 2)
# Number of movies: (3267, 2)
#          count  nunique
# movieId
# 1          215      215
# 2          110      110
# 3           52       52
# 4            7        7
# 5           49       49
# 6          102      102
# 7           54       54
# 8            8        8
# 9           16       16
# 10         132      132

# %%
np.random.seed(123)
random_indices = np.random.randint(0, len(merged_ratings), 500)
random_ratings = merged_ratings.iloc[random_indices]

# %% [markdown]
# ## Colaborative Filtering Matrix

# %%
merged_ratings = pd.merge(ratings, movies, on='movieId', how='inner')

# Drop not popular movies
merged_ratings =  merged_ratings[merged_ratings['movieId'].isin(movies_count.index)]

sparse_collabfitering = merged_ratings.pivot(index = "title", columns = "userId", values = "rating")
display(sparse_collabfitering.head(10))

sparse_collabfitering.shape
# Out:
# userId                                              1    2    3    4    5    \
# title
# 'burbs, The (1989)                                  NaN  NaN  NaN  NaN  NaN
# (500) Days of Summer (2009)                         NaN  NaN  NaN  NaN  NaN
# *batteries not included (1987)                      NaN  NaN  NaN  NaN  NaN
# 10 Cloverfield Lane (2016)                          NaN  NaN  NaN  NaN  NaN
# 10 Things I Hate About You (1999)                   NaN  NaN  NaN  NaN  NaN
# 10,000 BC (2008)                                    NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)                               NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  NaN  NaN  NaN  NaN  NaN
# 102 Dalmatians (2000)                               NaN  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)                                 NaN  NaN  NaN  2.5  NaN
#
# userId                                              6    7    8    9    10   \
# title
# 'burbs, The (1989)                                  NaN  NaN  NaN  NaN  NaN
# (500) Days of Summer (2009)                         NaN  NaN  NaN  NaN  NaN
# *batteries not included (1987)                      NaN  NaN  NaN  NaN  NaN
# 10 Cloverfield Lane (2016)                          NaN  NaN  NaN  NaN  NaN
# 10 Things I Hate About You (1999)                   NaN  NaN  NaN  NaN  NaN
# 10,000 BC (2008)                                    NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)                               NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  NaN  NaN  NaN  NaN  NaN
# 102 Dalmatians (2000)                               NaN  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)                                 NaN  NaN  NaN  NaN  NaN
#
# userId                                              ...  601  602  603  604  \
# title                                               ...
# 'burbs, The (1989)                                  ...  NaN  NaN  NaN  NaN
# (500) Days of Summer (2009)                         ...  NaN  NaN  NaN  NaN
# *batteries not included (1987)                      ...  NaN  NaN  NaN  NaN
# 10 Cloverfield Lane (2016)                          ...  NaN  NaN  NaN  NaN
# 10 Things I Hate About You (1999)                   ...  NaN  NaN  0.5  NaN
# 10,000 BC (2008)                                    ...  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)                               ...  NaN  NaN  1.5  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  ...  NaN  NaN  NaN  NaN
# 102 Dalmatians (2000)                               ...  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)                                 ...  2.5  NaN  NaN  NaN
#
# userId                                              605  606  607  608  609  \
# title
# 'burbs, The (1989)                                  NaN  NaN  NaN  NaN  NaN
# (500) Days of Summer (2009)                         NaN  NaN  NaN  NaN  NaN
# *batteries not included (1987)                      NaN  NaN  NaN  NaN  NaN
# 10 Cloverfield Lane (2016)                          NaN  NaN  NaN  NaN  NaN
# 10 Things I Hate About You (1999)                   2.5  NaN  NaN  NaN  NaN
# 10,000 BC (2008)                                    NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)                               0.5  NaN  NaN  NaN  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  NaN  NaN  NaN  NaN  NaN
# 102 Dalmatians (2000)                               0.5  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)                                 NaN  NaN  NaN  NaN  NaN
#
# userId                                              610
# title
# 'burbs, The (1989)                                  NaN
# (500) Days of Summer (2009)                         1.0
# *batteries not included (1987)                      NaN
# 10 Cloverfield Lane (2016)                          1.5
# 10 Things I Hate About You (1999)                   NaN
# 10,000 BC (2008)                                    NaN
# 101 Dalmatians (1996)                               NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  NaN
# 102 Dalmatians (2000)                               NaN
# 12 Angry Men (1957)                                 NaN
#
# [10 rows x 610 columns]
# (3267, 610)

# %%
sparse_matrix = csr_matrix(sparse_collabfitering)

# %%
n = len(sparse_collabfitering)
movie_similarity = np.zeros((n, n))

# %%
refresh_matrix = False
if refresh_matrix:
    for i in tqdm(range(n)):
        movies1_user = sparse_collabfitering.iloc[i, :].notna().to_numpy()
        
        for k in range(i+1, n):
            movies2_user = sparse_collabfitering.iloc[k, :].notna().to_numpy()

            # Calculate intersection using bitwise AND
            intersection_index = movies1_user & movies2_user

            # Check if there are common users
            if np.sum(intersection_index) >= 10:
                common_users = sparse_collabfitering.iloc[i, intersection_index].values
                other_movies = sparse_collabfitering.iloc[k, intersection_index].values
                
                movie_similarity[i, k] = cosine_similarity(common_users.reshape(1, -1), other_movies.reshape(1, -1))[0, 0]
                movie_similarity[k, i] = movie_similarity[i, k]

    movie_simDF = pd.DataFrame(movie_similarity, columns= sparse_collabfitering.index, index= sparse_collabfitering.index)
    movie_simDF.head(20)
    movie_simDF.to_csv("MtM_similarityMatrix.csv")

else:
    movie_similarity = pd.read_csv("MtM_similarityMatrix.csv", index_col=0)

# %% [markdown]
# Our cosine similarities are between 0 and 1 becasue ratings can only be positive

# %%
threshold = 0.8

movie_similarity_thresholded = np.where(movie_similarity > threshold, 1, 0)
movie_similarity_thresholded= pd.DataFrame(movie_similarity_thresholded)

# %%
G = nx.from_pandas_adjacency(movie_similarity_thresholded)
print(f"Total Edges: {len(G.edges())}")
# Out:
# Total Edges: 95227

# %%
import os
img_dir = '../latex/Images/'

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(12, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

degree_sequence = sorted((d for n, d in G.degree()), reverse=True)

# Calculate the CCDF
degrees, counts = np.unique(degree_sequence, return_counts=True)
ccdf = 1 - np.cumsum(counts) / np.sum(counts)

# Plot the CCDF
ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.loglog(degrees, ccdf, marker='o', linestyle='-')
ax1.set_title('Complementary Cumulative Distribution Function (CCDF)')
ax1.set_xlabel('Degree (log scale)')
ax1.set_ylabel('CCDF (log scale)')

#ax1 = fig.add_subplot(axgrid[3:, :2])
#ax1.plot(degree_sequence, "b-", marker="o")
#ax1.set_title("Degree Rank Plot")
#ax1.set_ylabel("Degree")
#ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.hist(degree_sequence, bins=30)
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

mean_degree = np.mean(degree_sequence)
median_degree = np.median(degree_sequence)

# Plot mean and median as vertical lines
ax2.axvline(x=mean_degree, color='red', linestyle='--', label=f'Mean: {mean_degree:.2f}')
ax2.axvline(x=median_degree, color='blue', linestyle='--', label=f'Median: {median_degree:.2f}')
ax2.legend()

#fig.tight_layout()
plt.savefig(os.path.join(img_dir, 'movie2movie_analysis.png'))
plt.show()

# %%
def plot_degree_histogram(g, normalized=True):
    print("Creating histogram...")
    aux_y = nx.degree_histogram(g)
    
    aux_x = np.arange(0,len(aux_y)).tolist()
    
    n_nodes = g.number_of_nodes()
    
    if normalized:
        for i in range(len(aux_y)):
            aux_y[i] = aux_y[i]/n_nodes
    
    return aux_x, aux_y

# %%
aux_x, aux_y = plot_degree_histogram(G, normalized=True)

plt.title('\nDistribution Of Node Linkages (log-log scale)')
plt.xlabel('Degree\n(log scale)')
plt.ylabel('Number of Nodes\n(log scale)')
plt.xscale("log")
plt.yscale("log")
plt.plot(aux_x, aux_y, 'o')
plt.show()
# Out:
# Creating histogram...

# %%
largest_cc = max(nx.connected_components(G), key=len)
subgraph = G.subgraph(largest_cc)

# %%
#fig, ax = plt.subplots(figsize=(16, 10))
#pos = nx.spring_layout(subgraph)

#nx.draw(subgraph, pos, with_labels=True, font_weight='bold', node_size=200, node_color='skyblue', font_color='black', font_size=8, edge_color='black', width=0.5)

#plt.title("Movie Similarity Network")
#plt.show()

# %% [markdown]
# # Community detection

# %%
#!pip install communities

# %%
print(f'N edges: {subgraph.number_of_edges()}')
print(f'N nodes: {subgraph.number_of_nodes()}')
# Out:
# N edges: 95219
# N nodes: 1848

# %%
communities = nx.community.greedy_modularity_communities(subgraph)
print(f'Number of communities: {len(communities)}')

keep_communities = []
for i, com in enumerate(communities):
    print(f'Community {i}: {len(com)}')
    if len(com) > 10 and i < 4:
        keep_communities.append(com)

print(f'\nModularity: {nx.community.modularity(subgraph, communities)}')
# Out:
# Number of communities: 10
# Community 0: 846
# Community 1: 821
# Community 2: 84
# Community 3: 79
# Community 4: 7
# Community 5: 3
# Community 6: 2
# Community 7: 2
# Community 8: 2
# Community 9: 2
#
# Modularity: 0.18163681877973514

# %%
for resolution in [0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3]:
    communities_ = nx.community.greedy_modularity_communities(subgraph, resolution=resolution)
    print(f'---- Resolution: {resolution}')
    print(f'Number of communities: {len(communities_)}')
    print(f'Modularity: {nx.community.modularity(subgraph, communities_)}')
# Out:
# ---- Resolution: 0.7
# Number of communities: 11
# Modularity: 0.0030673508496324104
# ---- Resolution: 0.8
# Number of communities: 11
# Modularity: 0.007504128234754282
# ---- Resolution: 0.9
# Number of communities: 13
# Modularity: 0.16984627562041105
# ---- Resolution: 1.0
# Number of communities: 10
# Modularity: 0.18163681877973514
# ---- Resolution: 1.1
# Number of communities: 11
# Modularity: 0.18448179397466963
# ---- Resolution: 1.2
# Number of communities: 13
# Modularity: 0.17874787942493997
# ---- Resolution: 1.3
# Number of communities: 18
# Modularity: 0.1697127998121027

# %%
# Calculate clustering coefficient for individual nodes
clustering_coefficients = nx.clustering(G)

# Calculate average clustering coefficient
avg_clustering_coefficient = nx.average_clustering(G)

# Print average clustering coefficient
print(f"\nAverage Clustering Coefficient = {avg_clustering_coefficient}")
# Out:
# Average Clustering Coefficient = 0.22351148429538897

# %%
colors = ['red', 'blue', 'orange', 'green']
node_colors_assignment = {}
for i, nodes in enumerate(keep_communities):
    for node in nodes:
        node_colors_assignment[node] = colors[i]

# %%
# Given subgraph and its communities
fig, ax = plt.subplots(figsize=(16, 10))

pos = nx.spring_layout(subgraph, seed=42, scale=1)  # Adjust the 'scale' parameter to spread out the graph

# Map node communities to colors
node_colors = [ node_colors_assignment[node] if node in node_colors_assignment else 'grey' for node in subgraph.nodes]

# Draw the subgraph with smaller nodes, smaller text, and visible edges
nx.draw(subgraph, pos, node_color=node_colors, node_size=50, alpha=0.5)

# Draw edges separately to make them more visible
nx.draw_networkx_edges(subgraph, pos, width=0.5, alpha=0.5)

plt.show()

# %%
# Generate a layout for the graph
pos = nx.spring_layout(subgraph, seed=42, scale=20)

# Filter nodes that have a color assignment
filtered_nodes = [node for node in subgraph.nodes if node in node_colors_assignment]

# Map node communities to colors
node_colors = [node_colors_assignment[node] for node in filtered_nodes]

# Draw the nodes
nx.draw(subgraph.subgraph(filtered_nodes), pos, node_color=node_colors, node_size=50, alpha=0.5)

# Draw edges separately to make them more visible
nx.draw_networkx_edges(subgraph.subgraph(filtered_nodes), pos, width=0.5, alpha=0.5)

plt.show()

# %%
from communities.algorithms import louvain_method

communities, _ = louvain_method(np.array(movie_similarity_thresholded))
# >>> [{0, 1, 2}, {3, 4, 5}]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 from communities.algorithms import louvain_method
# ----> 3 communities, _ = louvain_method(np.array(movie_similarity_thresholded))
#       4 # >>> [{0, 1, 2}, {3, 4, 5}]
#
# File ~/opt/anaconda3/envs/mlep-w1-lab/lib/python3.8/site-packages/communities/algorithms/louvain_method.py:158, in louvain_method(adj_matrix, n)
#     156 is_optimal = False
#     157 while not is_optimal:
# --> 158     optimal_node_to_comm, frames = run_first_phase(
#     159         node_to_comm,
#     160         optimal_adj_matrix,
#     161         n
#     162     )
#     164     if optimal_node_to_comm == node_to_comm:
#     165         if not n:
#
# File ~/opt/anaconda3/envs/mlep-w1-lab/lib/python3.8/site-packages/communities/algorithms/louvain_method.py:70, in run_first_phase(node_to_comm, adj_matrix, n, force_merge)
#      67 candidate_node_to_comm = best_node_to_comm.copy()
#      68 candidate_node_to_comm[i] = neighbor_comm
# ---> 70 candidate_Q = modularity(
#      71     M,
#      72     invert_node_to_comm(candidate_node_to_comm)
#      73 )
#      74 delta_Q = candidate_Q - best_Q
#      75 if delta_Q > max_delta_Q or (force_merge and not max_delta_Q):
#
# File ~/opt/anaconda3/envs/mlep-w1-lab/lib/python3.8/site-packages/communities/utilities.py:58, in modularity(mod_matrix, communities)
#      55         C[i, j] = 1.0
#      56         C[j, i] = 1.0
# ---> 58 return np.tril(np.multiply(mod_matrix, C), 0).sum()
#
# File <__array_function__ internals>:200, in tril(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlep-w1-lab/lib/python3.8/site-packages/numpy/lib/twodim_base.py:494, in tril(m, k)
#     491 m = asanyarray(m)
#     492 mask = tri(*m.shape[-2:], k=k, dtype=bool)
# --> 494 return where(mask, m, zeros(1, m.dtype))
#
# File <__array_function__ internals>:200, in where(*args, **kwargs)
#
# KeyboardInterrupt:
